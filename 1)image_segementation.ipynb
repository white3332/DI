# %%
# 사용한 라이브러리
import os
import json
import cv2
import numpy as np
import random

# 학습 데이터의 경로(이미지와 레이블)
image_dirs = [r".\original_data\image"]
label_dirs = [r".\original_data\label"] 

output_dir = r".\preprocessing_data"  # 저장 경로

# %%
# 이미지 전처리 함수
def preprocess_image(image, operations):
    # 그레이스케일 변환, 흑백 이미지로 변환
    if 'gray_scale' in operations:
        image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    # 임계값 처리
    if 'thresholding' in operations:
        _, image = cv2.threshold(image, 128, 255, cv2.THRESH_BINARY)
        
    if 'adaptive_thresholding' in operations:
        block_size, constant = 9, 3
        image = cv2.adaptiveThreshold(
            image, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, block_size, constant
            )
    
    if 'otsu_thresholding' in operations:
        _, image = cv2.threshold(image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    
    # 블러링
    if 'blur' in operations:
        image = cv2.GaussianBlur(image, (5, 5), 0)
    
    # 투시 변환
    if 'perspective_transform_augmentation' in operations:
        # 원본 이미지의 크기 얻기
        height, width = image.shape[:2]
        
        # 변환 전 이미지의 꼭짓점을 변수에 할당
        pts1 = np.float32([[0, 0], [width - 1, 0], [width - 1, height - 1], [0, height - 1]])
        
        # 각각 이미지 내에서 임의의 좌표를 설정
        # distortion_factor: 이동 비율 
        distortion_factor=0.2
        pts2 = np.float32([
            [random.randint(0, int(width * distortion_factor)),
            random.randint(0, int(height * distortion_factor))],  # 왼쪽 상단
            [random.randint(int(width * (1-distortion_factor)), width),
            random.randint(0, int(height * distortion_factor))],  # 오른쪽 상단
            [random.randint(int(width * (1-distortion_factor)), width),
            random.randint(int(height * (1-distortion_factor)), height)],  # 오른쪽 하단
            [random.randint(0, int(width * distortion_factor)),
            random.randint(int(height * (1-distortion_factor)), height)]  # 왼쪽 하단
        ])
        
        # 원근 변환 행렬 계산
        mtrx = cv2.getPerspectiveTransform(pts1, pts2)
        
        # 원근 변환 적용 (이미지를 정해진 좌표로 변환)
        # 출력 이미지 크기를 원본보다 크게 설정 (예: 1.15배)
        new_width = int(width * (1.0 + distortion_factor))
        new_height = int(height * (1.0 + distortion_factor))
        
        # 변환된 이미지를 새로운 크기로 변환
        transformed_image = cv2.warpPerspective(image, mtrx, (new_width, new_height))
        
        # 출력된 이미지에서 원하는 영역만 잘라냄 (기존 이미지 크기만큼)
        start_x = (new_width - width) // 2
        start_y = (new_height - height) // 2
        
        # 변환된 이미지의 중앙에 기존 이미지 크기를 맞추어 자르기
        image = transformed_image[0:start_y + height, 0:start_x + width]

    return image

# 사용자 정의 전처리 작업 리스트
preprocessing_operations = ['gray_scale', 'adaptive_thresholding', 'blur']

# %%
# 이미지 파일 이름 카운터
file_count = 1  
# 출력 디렉토리 생성
os.makedirs(output_dir, exist_ok=True)

for index, label_dir in enumerate(label_dirs):
    output_file = os.path.join(output_dir, "train.txt")
    Type = "train"
    
    with open(output_file, "w", encoding="utf-8") as label_file:
        for json_file in os.listdir(label_dir):
            if json_file.endswith(".json"):
                json_path = os.path.join(label_dir, json_file)
                
                # JSON 파일 읽기
                with open(json_path, "r", encoding="utf-8") as f:
                    data = json.load(f)
                
                # 이미지 파일 로드
                image_id = data["Images"]["identifier"]
                image_type = data["Images"]["type"]
                image_path = os.path.join(image_dirs[index], f"{image_id}.{image_type}")
                image = cv2.imread(image_path)
                
                if image is None:
                    print(f"Failed to load image: {image_path}")
                    continue
                
                # Bbox 데이터 처리
                for bbox in data.get("Bbox", []):
                    x_coords = bbox.get("x", [])
                    y_coords = bbox.get("y", [])
                    text = bbox.get("data", "").strip()
                    
                    print(text)
                    # 텍스트 저장
                    if text:
                        label_file.write(f"{Type}/word{file_count}.png\t{text}\n")
                    
                    # 부분 이미지 저장
                    if len(x_coords) == 4 and len(y_coords) == 4:
                        x1, y1 = min(x_coords), min(y_coords)
                        x2, y2 = max(x_coords), max(y_coords)
                        
                        if x2 > x1 and y2 > y1:  # 유효한 바운딩 박스인지 확인
                            sub_image = image[y1:y2, x1:x2]
                            
                            # 이미지 저장 경로 설정
                            output_image_dir = os.path.join(output_dir, Type)
                            os.makedirs(output_image_dir, exist_ok=True)  # Type별 서브디렉토리 생성
                            
                            # 전처리 전 이미지 저장
                            output_path = os.path.join(output_image_dir, f"word{file_count}_ori.png")
                            cv2.imwrite(output_path, sub_image)
                            
                            # 전처리 후 이미지 저장
                            output_path = os.path.join(output_image_dir, f"word{file_count}_pre.png")
                            sub_image = preprocess_image(sub_image, preprocessing_operations)
                            cv2.imwrite(output_path, sub_image)
                            
                            print(f"Saved: {output_path}")
                            file_count += 1
                        else:
                            print(f"Invalid bounding box in {json_path}: {x_coords}, {y_coords}")
# Out:
# 지남에
# Saved: .\preprocessing_data\train\word1_pre.png
# 시간이
# Saved: .\preprocessing_data\train\word2_pre.png
# 세상이
# Saved: .\preprocessing_data\train\word3_pre.png
# 믿는다면
# Saved: .\preprocessing_data\train\word4_pre.png
# 증거를
# Saved: .\preprocessing_data\train\word5_pre.png
# 것이다
# Saved: .\preprocessing_data\train\word6_pre.png
# 해도
# Saved: .\preprocessing_data\train\word7_pre.png
# 보아라
# Saved: .\preprocessing_data\train\word8_pre.png
# 열렬@
# Saved: .\preprocessing_data\train\word9_pre.png
# 편을
# Saved: .\preprocessing_data\train\word10_pre.png
# @은
# Saved: .\preprocessing_data\train\word11_pre.png
# 1
# Saved: .\preprocessing_data\train\word12_pre.png
# 변@에
# Saved: .\preprocessing_data\train\word13_pre.png
# 대한
# Saved: .\preprocessing_data\train\word14_pre.png
# 저항력이
# Saved: .\preprocessing_data\train\word15_pre.png
# 매우
# Saved: .\preprocessing_data\train\word16_pre.png
# 강@다
# Saved: .\preprocessing_data\train\word17_pre.png
# 2
# Saved: .\preprocessing_data\train\word18_pre.png
# 일반적인
# Saved: .\preprocessing_data\train\word19_pre.png
# 믿음은
# Saved: .\preprocessing_data\train\word20_pre.png
# 충분안
# Saved: .\preprocessing_data\train\word21_pre.png
# 논쟁에
# Saved: .\preprocessing_data\train\word22_pre.png
# 직면아여
# Saved: .\preprocessing_data\train\word23_pre.png
# 따라
# Saved: .\preprocessing_data\train\word24_pre.png
# 변알
# Saved: .\preprocessing_data\train\word25_pre.png
# 수
# Saved: .\preprocessing_data\train\word26_pre.png
# 있다
# Saved: .\preprocessing_data\train\word27_pre.png
# 3
# Saved: .\preprocessing_data\train\word28_pre.png
# 만약
# Saved: .\preprocessing_data\train\word29_pre.png
# 너가
# Saved: .\preprocessing_data\train\word30_pre.png
# 평평@다고
# Saved: .\preprocessing_data\train\word31_pre.png
# 예를
# Saved: .\preprocessing_data\train\word32_pre.png
# 들어,
# Saved: .\preprocessing_data\train\word33_pre.png
# 나는
# Saved: .\preprocessing_data\train\word34_pre.png
# 아마도
# Saved: .\preprocessing_data\train\word35_pre.png
# 너에게
# Saved: .\preprocessing_data\train\word36_pre.png
# 의견을
# Saved: .\preprocessing_data\train\word37_pre.png
# 바꿀
# Saved: .\preprocessing_data\train\word38_pre.png
# 수
# Saved: .\preprocessing_data\train\word39_pre.png
# 있는
# Saved: .\preprocessing_data\train\word40_pre.png
# 충분한
# Saved: .\preprocessing_data\train\word41_pre.png
# 제공알
# Saved: .\preprocessing_data\train\word42_pre.png
# 수
# Saved: .\preprocessing_data\train\word43_pre.png
# 있을
# Saved: .\preprocessing_data\train\word44_pre.png
# 4
# Saved: .\preprocessing_data\train\word45_pre.png
# 그러나
# Saved: .\preprocessing_data\train\word46_pre.png
# 반론이
# Saved: .\preprocessing_data\train\word47_pre.png
# 아무리
# Saved: .\preprocessing_data\train\word48_pre.png
# 설득력이
# Saved: .\preprocessing_data\train\word49_pre.png
# 있다
# Saved: .\preprocessing_data\train\word50_pre.png
# 가치는
# Saved: .\preprocessing_data\train\word51_pre.png
# 거의
# Saved: .\preprocessing_data\train\word52_pre.png
# 변하지
# Saved: .\preprocessing_data\train\word53_pre.png
# @는다
# Saved: .\preprocessing_data\train\word54_pre.png
# 5
# Saved: .\preprocessing_data\train\word55_pre.png
# 6
# Saved: .\preprocessing_data\train\word56_pre.png
# 진@론에
# Saved: .\preprocessing_data\train\word57_pre.png
# 대@`
# Saved: .\preprocessing_data\train\word58_pre.png
# 논쟁을
# Saved: .\preprocessing_data\train\word59_pre.png
# 생각해
# Saved: .\preprocessing_data\train\word60_pre.png
# 만약
# Saved: .\preprocessing_data\train\word61_pre.png
# 너가
# Saved: .\preprocessing_data\train\word62_pre.png
# 과학에
# Saved: .\preprocessing_data\train\word63_pre.png
# 대한
# Saved: .\preprocessing_data\train\word64_pre.png
# 신봉자라면
# Saved: .\preprocessing_data\train\word65_pre.png
# 너는
# Saved: .\preprocessing_data\train\word66_pre.png
# 결코
# Saved: .\preprocessing_data\train\word67_pre.png
# 창조론자의
# Saved: .\preprocessing_data\train\word68_pre.png
# 수
# Saved: .\preprocessing_data\train\word69_pre.png
# 없을
# Saved: .\preprocessing_data\train\word70_pre.png
# 것이다
# Saved: .\preprocessing_data\train\word71_pre.png
# 들
# Saved: .\preprocessing_data\train\word72_pre.png
# 믿는다면
# Saved: .\preprocessing_data\train\word73_pre.png
# 의견에
# Saved: .\preprocessing_data\train\word74_pre.png
# 없다
# Saved: .\preprocessing_data\train\word75_pre.png
# 어느
# Saved: .\preprocessing_data\train\word76_pre.png
# 상대방의
# Saved: .\preprocessing_data\train\word77_pre.png
# 주장의
# Saved: .\preprocessing_data\train\word78_pre.png
# 이해하지
# Saved: .\preprocessing_data\train\word79_pre.png
# 못할
# Saved: .\preprocessing_data\train\word80_pre.png
# 설득력이
# Saved: .\preprocessing_data\train\word81_pre.png
# 있다고
# Saved: .\preprocessing_data\train\word82_pre.png
# 믿음이
# Saved: .\preprocessing_data\train\word83_pre.png
# 깊이
# Saved: .\preprocessing_data\train\word84_pre.png
# 반면에
# Saved: .\preprocessing_data\train\word85_pre.png
# 7
# Saved: .\preprocessing_data\train\word86_pre.png
# 만약
# Saved: .\preprocessing_data\train\word87_pre.png
# 너가
# Saved: .\preprocessing_data\train\word88_pre.png
# 우주가
# Saved: .\preprocessing_data\train\word89_pre.png
# 신에
# Saved: .\preprocessing_data\train\word90_pre.png
# 의해
# Saved: .\preprocessing_data\train\word91_pre.png
# 장조되었다고
# Saved: .\preprocessing_data\train\word92_pre.png
# 너는
# Saved: .\preprocessing_data\train\word93_pre.png
# 진화론자들의
# Saved: .\preprocessing_data\train\word94_pre.png
# 수
# Saved: .\preprocessing_data\train\word95_pre.png
# 동의할
# Saved: .\preprocessing_data\train\word96_pre.png
# 8
# Saved: .\preprocessing_data\train\word97_pre.png
# 9
# Saved: .\preprocessing_data\train\word98_pre.png
# 반론이
# Saved: .\preprocessing_data\train\word99_pre.png
# 타당성을
# Saved: .\preprocessing_data\train\word100_pre.png
# 아무리
# Saved: .\preprocessing_data\train\word101_pre.png
# 합리적이고
# Saved: .\preprocessing_data\train\word102_pre.png
# 것이다
# Saved: .\preprocessing_data\train\word103_pre.png
# 사실적이거나
# Saved: .\preprocessing_data\train\word104_pre.png
# 해도
# Saved: .\preprocessing_data\train\word105_pre.png
# 그
# Saved: .\preprocessing_data\train\word106_pre.png
# 가치일
# Saved: .\preprocessing_data\train\word107_pre.png
# 때
# Saved: .\preprocessing_data\train\word108_pre.png
# 그것은
# Saved: .\preprocessing_data\train\word109_pre.png
# 결코
# Saved: .\preprocessing_data\train\word110_pre.png
# 누군가를
# Saved: .\preprocessing_data\train\word111_pre.png
# 간직하고
# Saved: .\preprocessing_data\train\word112_pre.png
# 있는
# Saved: .\preprocessing_data\train\word113_pre.png
# 믿음으로부터
# Saved: .\preprocessing_data\train\word114_pre.png
# 만류하지
# Saved: .\preprocessing_data\train\word115_pre.png
# 않을
# Saved: .\preprocessing_data\train\word116_pre.png
# 것이다
# Saved: .\preprocessing_data\train\word117_pre.png
# 쪽도
# Saved: .\preprocessing_data\train\word118_pre.png
# 22.6.7
# Saved: .\preprocessing_data\train\word119_pre.png
# The
# Saved: .\preprocessing_data\train\word120_pre.png
# Human
# Saved: .\preprocessing_data\train\word121_pre.png
# Liver
# Saved: .\preprocessing_data\train\word122_pre.png
# Vitamin:
# Saved: .\preprocessing_data\train\word123_pre.png
# 비타민
# Saved: .\preprocessing_data\train\word124_pre.png
# alcohol:
# Saved: .\preprocessing_data\train\word125_pre.png
# 알코올
# Saved: .\preprocessing_data\train\word126_pre.png
# bacteria:
# Saved: .\preprocessing_data\train\word127_pre.png
# 박테리아.
# Saved: .\preprocessing_data\train\word128_pre.png
# caffeine:
# Saved: .\preprocessing_data\train\word129_pre.png
# 카페인
# Saved: .\preprocessing_data\train\word130_pre.png
# blood
# Saved: .\preprocessing_data\train\word131_pre.png
# 피
# Saved: .\preprocessing_data\train\word132_pre.png
# human
# Saved: .\preprocessing_data\train\word133_pre.png
# in
# Saved: .\preprocessing_data\train\word134_pre.png
# role
# Saved: .\preprocessing_data\train\word135_pre.png
# important
# Saved: .\preprocessing_data\train\word136_pre.png
# an
# Saved: .\preprocessing_data\train\word137_pre.png
# plays
# Saved: .\preprocessing_data\train\word138_pre.png
# that
# Saved: .\preprocessing_data\train\word139_pre.png
# organ
# Saved: .\preprocessing_data\train\word140_pre.png
# Liver
# Saved: .\preprocessing_data\train\word141_pre.png
# 흡수하다.
# Saved: .\preprocessing_data\train\word142_pre.png
# absorb:
# Saved: .\preprocessing_data\train\word143_pre.png
# bone:
# Saved: .\preprocessing_data\train\word144_pre.png
# 뼈
# Saved: .\preprocessing_data\train\word145_pre.png
# health:
# Saved: .\preprocessing_data\train\word146_pre.png
# 건강
# Saved: .\preprocessing_data\train\word147_pre.png
# vital
# Saved: .\preprocessing_data\train\word148_pre.png
# a
# Saved: .\preprocessing_data\train\word149_pre.png
# is
# Saved: .\preprocessing_data\train\word150_pre.png
# liver
# Saved: .\preprocessing_data\train\word151_pre.png
# The
# Saved: .\preprocessing_data\train\word152_pre.png
# The
# Saved: .\preprocessing_data\train\word153_pre.png
# Human
# Saved: .\preprocessing_data\train\word154_pre.png
# metabolism
# Saved: .\preprocessing_data\train\word155_pre.png
# Liver
# Saved: .\preprocessing_data\train\word156_pre.png
# Human
# Saved: .\preprocessing_data\train\word157_pre.png
# The
# Saved: .\preprocessing_data\train\word158_pre.png
# 7
# Saved: .\preprocessing_data\train\word159_pre.png
# 6
# Saved: .\preprocessing_data\train\word160_pre.png
# 22
# Saved: .\preprocessing_data\train\word161_pre.png
# 비타민,
# Saved: .\preprocessing_data\train\word162_pre.png
# Vitamin:
# Saved: .\preprocessing_data\train\word163_pre.png
# alcohol:
# Saved: .\preprocessing_data\train\word164_pre.png
# 알코올,
# Saved: .\preprocessing_data\train\word165_pre.png
# bacteria:
# Saved: .\preprocessing_data\train\word166_pre.png
# 박테리아,
# Saved: .\preprocessing_data\train\word167_pre.png
# caffeine:
# Saved: .\preprocessing_data\train\word168_pre.png
# 카페인,
# Saved: .\preprocessing_data\train\word169_pre.png
# blood:
# Saved: .\preprocessing_data\train\word170_pre.png
# 피
# Saved: .\preprocessing_data\train\word171_pre.png
# human
# Saved: .\preprocessing_data\train\word172_pre.png
# in
# Saved: .\preprocessing_data\train\word173_pre.png
# role
# Saved: .\preprocessing_data\train\word174_pre.png
# important
# Saved: .\preprocessing_data\train\word175_pre.png
# an
# Saved: .\preprocessing_data\train\word176_pre.png
# plays
# Saved: .\preprocessing_data\train\word177_pre.png
# that
# Saved: .\preprocessing_data\train\word178_pre.png
# 건강
# Saved: .\preprocessing_data\train\word179_pre.png
# health:
# Saved: .\preprocessing_data\train\word180_pre.png
# 뼈
# Saved: .\preprocessing_data\train\word181_pre.png
# bone:
# Saved: .\preprocessing_data\train\word182_pre.png
# 흡수하다.
# Saved: .\preprocessing_data\train\word183_pre.png
# absorb:
# Saved: .\preprocessing_data\train\word184_pre.png
# The
# Saved: .\preprocessing_data\train\word185_pre.png
# Human
# Saved: .\preprocessing_data\train\word186_pre.png
# Liver
# Saved: .\preprocessing_data\train\word187_pre.png
# The
# Saved: .\preprocessing_data\train\word188_pre.png
# liver
# Saved: .\preprocessing_data\train\word189_pre.png
# is
# Saved: .\preprocessing_data\train\word190_pre.png
# a
# Saved: .\preprocessing_data\train\word191_pre.png
# vital
# Saved: .\preprocessing_data\train\word192_pre.png
# organ
# Saved: .\preprocessing_data\train\word193_pre.png
# metabolism
# Saved: .\preprocessing_data\train\word194_pre.png
# creates
# Saved: .\preprocessing_data\train\word195_pre.png
# digestive
# Saved: .\preprocessing_data\train\word196_pre.png
# process
# Saved: .\preprocessing_data\train\word197_pre.png
# and
# Saved: .\preprocessing_data\train\word198_pre.png
# Stores
# Saved: .\preprocessing_data\train\word199_pre.png
# nutrients
# Saved: .\preprocessing_data\train\word200_pre.png
# for
# Saved: .\preprocessing_data\train\word201_pre.png
# later
# Saved: .\preprocessing_data\train\word202_pre.png
# use
# Saved: .\preprocessing_data\train\word203_pre.png
# liver
# Saved: .\preprocessing_data\train\word204_pre.png
# helps
# Saved: .\preprocessing_data\train\word205_pre.png
# remove
# Saved: .\preprocessing_data\train\word206_pre.png
# dangerous
# Saved: .\preprocessing_data\train\word207_pre.png
# substances
# Saved: .\preprocessing_data\train\word208_pre.png
# from
# Saved: .\preprocessing_data\train\word209_pre.png
# the
# Saved: .\preprocessing_data\train\word210_pre.png
# blood
# Saved: .\preprocessing_data\train\word211_pre.png
# circulation
# Saved: .\preprocessing_data\train\word212_pre.png
# produces
# Saved: .\preprocessing_data\train\word213_pre.png
# blood
# Saved: .\preprocessing_data\train\word214_pre.png
# protein
# Saved: .\preprocessing_data\train\word215_pre.png
# control
# Saved: .\preprocessing_data\train\word216_pre.png
# medicine
# Saved: .\preprocessing_data\train\word217_pre.png
# flow
# Saved: .\preprocessing_data\train\word218_pre.png
# The
# Saved: .\preprocessing_data\train\word219_pre.png
# liver
# Saved: .\preprocessing_data\train\word220_pre.png
# bile
# Saved: .\preprocessing_data\train\word221_pre.png
# to
# Saved: .\preprocessing_data\train\word222_pre.png
# help
# Saved: .\preprocessing_data\train\word223_pre.png
# the
# Saved: .\preprocessing_data\train\word224_pre.png
# The
# Saved: .\preprocessing_data\train\word225_pre.png
# The
# Saved: .\preprocessing_data\train\word226_pre.png
# liver
# Saved: .\preprocessing_data\train\word227_pre.png
# and
# Saved: .\preprocessing_data\train\word228_pre.png
# Stop
# Saved: .\preprocessing_data\train\word229_pre.png
# bleeding
# Saved: .\preprocessing_data\train\word230_pre.png
# that
# Saved: .\preprocessing_data\train\word231_pre.png
# helps
# Saved: .\preprocessing_data\train\word232_pre.png
# to
# Saved: .\preprocessing_data\train\word233_pre.png
# thus
# Saved: .\preprocessing_data\train\word234_pre.png
# improving
# Saved: .\preprocessing_data\train\word235_pre.png
# a
# Saved: .\preprocessing_data\train\word236_pre.png
# -
# Saved: .\preprocessing_data\train\word237_pre.png
# -
# Saved: .\preprocessing_data\train\word238_pre.png
# -
# Saved: .\preprocessing_data\train\word239_pre.png
# 22
# Saved: .\preprocessing_data\train\word240_pre.png
# 6
# Saved: .\preprocessing_data\train\word241_pre.png
# 8
# Saved: .\preprocessing_data\train\word242_pre.png
# 추론
# Saved: .\preprocessing_data\train\word243_pre.png
# organism
# Saved: .\preprocessing_data\train\word244_pre.png
# 유기체
# Saved: .\preprocessing_data\train\word245_pre.png
# natural
# Saved: .\preprocessing_data\train\word246_pre.png
# selection
# Saved: .\preprocessing_data\train\word247_pre.png
# 자연선택
# Saved: .\preprocessing_data\train\word248_pre.png
# author
# Saved: .\preprocessing_data\train\word249_pre.png
# 저자
# Saved: .\preprocessing_data\train\word250_pre.png
# tease
# Saved: .\preprocessing_data\train\word251_pre.png
# 놀리다
# Saved: .\preprocessing_data\train\word252_pre.png
# stray
# Saved: .\preprocessing_data\train\word253_pre.png
# dog
# Saved: .\preprocessing_data\train\word254_pre.png
# 유기견
# Saved: .\preprocessing_data\train\word255_pre.png
# lifeling
# Saved: .\preprocessing_data\train\word256_pre.png
# 평생인
# Saved: .\preprocessing_data\train\word257_pre.png
# furiously
# Saved: .\preprocessing_data\train\word258_pre.png
# 맹렬히
# Saved: .\preprocessing_data\train\word259_pre.png
# 60p
# Saved: .\preprocessing_data\train\word260_pre.png
# 근본적으로
# Saved: .\preprocessing_data\train\word261_pre.png
# 진화
# Saved: .\preprocessing_data\train\word262_pre.png
# 이론의
# Saved: .\preprocessing_data\train\word263_pre.png
# 주제였고
# Saved: .\preprocessing_data\train\word264_pre.png
# 1809년
# Saved: .\preprocessing_data\train\word265_pre.png
# 라마르크에
# Saved: .\preprocessing_data\train\word266_pre.png
# 제시되었다
# Saved: .\preprocessing_data\train\word267_pre.png
# 그들의
# Saved: .\preprocessing_data\train\word268_pre.png
# 아이들에게
# Saved: .\preprocessing_data\train\word269_pre.png
# 아이디어는
# Saved: .\preprocessing_data\train\word270_pre.png
# 유기체들이
# Saved: .\preprocessing_data\train\word271_pre.png
# 그들의
# Saved: .\preprocessing_data\train\word272_pre.png
# 선천적인
# Saved: .\preprocessing_data\train\word273_pre.png
# 교수들은
# Saved: .\preprocessing_data\train\word274_pre.png
# 근육질의
# Saved: .\preprocessing_data\train\word275_pre.png
# 아기를
# Saved: .\preprocessing_data\train\word276_pre.png
# 그리고
# Saved: .\preprocessing_data\train\word277_pre.png
# 1번
# Saved: .\preprocessing_data\train\word278_pre.png
# 프랑스
# Saved: .\preprocessing_data\train\word279_pre.png
# 생물학자
# Saved: .\preprocessing_data\train\word280_pre.png
# 장밥티스트
# Saved: .\preprocessing_data\train\word281_pre.png
# 있는가
# Saved: .\preprocessing_data\train\word282_pre.png
# 가지고
# Saved: .\preprocessing_data\train\word283_pre.png
# 이론보다
# Saved: .\preprocessing_data\train\word284_pre.png
# 앞선
# Saved: .\preprocessing_data\train\word285_pre.png
# 다윈의
# Saved: .\preprocessing_data\train\word286_pre.png
# 아기를
# Saved: .\preprocessing_data\train\word287_pre.png
# 근육질의
# Saved: .\preprocessing_data\train\word288_pre.png
# 1
# Saved: .\preprocessing_data\train\word289_pre.png
# 2
# Saved: .\preprocessing_data\train\word290_pre.png
# 보디빌더들은
# Saved: .\preprocessing_data\train\word291_pre.png
# 그것은
# Saved: .\preprocessing_data\train\word292_pre.png
# 의해
# Saved: .\preprocessing_data\train\word293_pre.png
# 3
# Saved: .\preprocessing_data\train\word294_pre.png
# 그
# Saved: .\preprocessing_data\train\word295_pre.png
# 특성뿐만
# Saved: .\preprocessing_data\train\word296_pre.png
# 아니라
# Saved: .\preprocessing_data\train\word297_pre.png
# 그들이
# Saved: .\preprocessing_data\train\word298_pre.png
# 삶에서
# Saved: .\preprocessing_data\train\word299_pre.png
# 것이었다
# Saved: .\preprocessing_data\train\word300_pre.png
# 물려준다는
# Saved: .\preprocessing_data\train\word301_pre.png
# 4
# Saved: .\preprocessing_data\train\word302_pre.png
# 그래서
# Saved: .\preprocessing_data\train\word303_pre.png
# 똑똑한
# Saved: .\preprocessing_data\train\word304_pre.png
# 아이들을
# Saved: .\preprocessing_data\train\word305_pre.png
# 가지고
# Saved: .\preprocessing_data\train\word306_pre.png
# 있고
# Saved: .\preprocessing_data\train\word307_pre.png
# 습득한
# Saved: .\preprocessing_data\train\word308_pre.png
# 것들도
# Saved: .\preprocessing_data\train\word309_pre.png
# 가지고
# Saved: .\preprocessing_data\train\word310_pre.png
# 있다
# Saved: .\preprocessing_data\train\word311_pre.png
# 실제로
# Saved: .\preprocessing_data\train\word312_pre.png
# 보디빌더들은
# Saved: .\preprocessing_data\train\word313_pre.png
# 기린은
# Saved: .\preprocessing_data\train\word314_pre.png
# 그들의
# Saved: .\preprocessing_data\train\word315_pre.png
# 긴목을
# Saved: .\preprocessing_data\train\word316_pre.png
# 길렀다.
# Saved: .\preprocessing_data\train\word317_pre.png
# 다윈의
# Saved: .\preprocessing_data\train\word318_pre.png
# 자연
# Saved: .\preprocessing_data\train\word319_pre.png
# 증가하고
# Saved: .\preprocessing_data\train\word320_pre.png
# 인기가
# Saved: .\preprocessing_data\train\word321_pre.png
# 높아지면서
# Saved: .\preprocessing_data\train\word322_pre.png
# 라마르크의
# Saved: .\preprocessing_data\train\word323_pre.png
# 진화론을
# Saved: .\preprocessing_data\train\word324_pre.png
# 증거는
# Saved: .\preprocessing_data\train\word325_pre.png
# 아이디어는
# Saved: .\preprocessing_data\train\word326_pre.png
# 증거가
# Saved: .\preprocessing_data\train\word327_pre.png
# 대한
# Saved: .\preprocessing_data\train\word328_pre.png
# 떨어졌다.
# Saved: .\preprocessing_data\train\word329_pre.png
# 인기가
# Saved: .\preprocessing_data\train\word330_pre.png
# 그
# Saved: .\preprocessing_data\train\word331_pre.png
# 않았고,
# Saved: .\preprocessing_data\train\word332_pre.png
# 게리
# Saved: .\preprocessing_data\train\word333_pre.png
# 스미스는
# Saved: .\preprocessing_data\train\word334_pre.png
# 악명높은
# Saved: .\preprocessing_data\train\word335_pre.png
# 거리,
# Saved: .\preprocessing_data\train\word336_pre.png
# 토니
# Saved: .\preprocessing_data\train\word337_pre.png
# 터커의
# Saved: .\preprocessing_data\train\word338_pre.png
# 이론에
# Saved: .\preprocessing_data\train\word339_pre.png
# 이론화했듯이,
# Saved: .\preprocessing_data\train\word340_pre.png
# 많은
# Saved: .\preprocessing_data\train\word341_pre.png
# 세대의
# Saved: .\preprocessing_data\train\word342_pre.png
# 실제로
# Saved: .\preprocessing_data\train\word343_pre.png
# 동물들이
# Saved: .\preprocessing_data\train\word344_pre.png
# ,나무
# Saved: .\preprocessing_data\train\word345_pre.png
# 꼭대기의
# Saved: .\preprocessing_data\train\word346_pre.png
# 거의
# Saved: .\preprocessing_data\train\word347_pre.png
# 나오지
# Saved: .\preprocessing_data\train\word348_pre.png
# 작가인
# Saved: .\preprocessing_data\train\word349_pre.png
# 소설의
# Saved: .\preprocessing_data\train\word350_pre.png
# 십대
# Saved: .\preprocessing_data\train\word351_pre.png
# 때,
# Saved: .\preprocessing_data\train\word352_pre.png
# 십대였을
# Saved: .\preprocessing_data\train\word353_pre.png
# 1번
# Saved: .\preprocessing_data\train\word354_pre.png
# 도달하려고
# Saved: .\preprocessing_data\train\word355_pre.png
# 잎사귀에
# Saved: .\preprocessing_data\train\word356_pre.png
# 가장
# Saved: .\preprocessing_data\train\word357_pre.png
# 사랑받는
# Saved: .\preprocessing_data\train\word358_pre.png
# 희생자였다.
# Saved: .\preprocessing_data\train\word359_pre.png
# 노력하면서
# Saved: .\preprocessing_data\train\word360_pre.png
# 뒷받침할
# Saved: .\preprocessing_data\train\word361_pre.png
# 선택
# Saved: .\preprocessing_data\train\word362_pre.png
# 그러나
# Saved: .\preprocessing_data\train\word363_pre.png
# 5.
# Saved: .\preprocessing_data\train\word364_pre.png
# 64P
# Saved: .\preprocessing_data\train\word365_pre.png
# 1.
# Saved: .\preprocessing_data\train\word366_pre.png
# 라마르크가
# Saved: .\preprocessing_data\train\word367_pre.png
# 골목길을
# Saved: .\preprocessing_data\train\word368_pre.png
# 사나워
# Saved: .\preprocessing_data\train\word369_pre.png
# 햄버거의
# Saved: .\preprocessing_data\train\word370_pre.png
# 2
# Saved: .\preprocessing_data\train\word371_pre.png
# 어느날
# Saved: .\preprocessing_data\train\word372_pre.png
# 밤늦게
# Saved: .\preprocessing_data\train\word373_pre.png
# 그가
# Saved: .\preprocessing_data\train\word374_pre.png
# 레스토랑을
# Saved: .\preprocessing_data\train\word375_pre.png
# 떠나면서
# Saved: .\preprocessing_data\train\word376_pre.png
# 게리는
# Saved: .\preprocessing_data\train\word377_pre.png
# 토니에게
# Saved: .\preprocessing_data\train\word378_pre.png
# 놀림을
# Saved: .\preprocessing_data\train\word379_pre.png
# 받곤했던
# Saved: .\preprocessing_data\train\word380_pre.png
# 떠나
# Saved: .\preprocessing_data\train\word381_pre.png
# 오는
# Saved: .\preprocessing_data\train\word382_pre.png
# 것을
# Saved: .\preprocessing_data\train\word383_pre.png
# 보았다
# Saved: .\preprocessing_data\train\word384_pre.png
# 밟았다
# Saved: .\preprocessing_data\train\word385_pre.png
# 유기견을
# Saved: .\preprocessing_data\train\word386_pre.png
# 보이는
# Saved: .\preprocessing_data\train\word387_pre.png
# 길
# Saved: .\preprocessing_data\train\word388_pre.png
# 끝에서
# Saved: .\preprocessing_data\train\word389_pre.png
# 토니가
# Saved: .\preprocessing_data\train\word390_pre.png
# 그는
# Saved: .\preprocessing_data\train\word391_pre.png
# 던졌다
# Saved: .\preprocessing_data\train\word392_pre.png
# 개에게
# Saved: .\preprocessing_data\train\word393_pre.png
# 반을
# Saved: .\preprocessing_data\train\word394_pre.png
# 그는
# Saved: .\preprocessing_data\train\word395_pre.png
# 5
# Saved: .\preprocessing_data\train\word396_pre.png
# 4
# Saved: .\preprocessing_data\train\word397_pre.png
# 3
# Saved: .\preprocessing_data\train\word398_pre.png
# 집으로
# Saved: .\preprocessing_data\train\word399_pre.png
# 가는
# Saved: .\preprocessing_data\train\word400_pre.png
# 새로운
# Saved: .\preprocessing_data\train\word401_pre.png
# 길을
# Saved: .\preprocessing_data\train\word402_pre.png
# 찾으려고
# Saved: .\preprocessing_data\train\word403_pre.png
# 했다
# Saved: .\preprocessing_data\train\word404_pre.png
# 들어갔을때
# Saved: .\preprocessing_data\train\word405_pre.png
# 거리에
# Saved: .\preprocessing_data\train\word406_pre.png
# 새로운
# Saved: .\preprocessing_data\train\word407_pre.png
# 그가
# Saved: .\preprocessing_data\train\word408_pre.png
# 그러나
# Saved: .\preprocessing_data\train\word409_pre.png
# 불량배를
# Saved: .\preprocessing_data\train\word410_pre.png
# 피하기
# Saved: .\preprocessing_data\train\word411_pre.png
# 위해
# Saved: .\preprocessing_data\train\word412_pre.png
# 그는
# Saved: .\preprocessing_data\train\word413_pre.png
# 재빨리
# Saved: .\preprocessing_data\train\word414_pre.png
# 뒤로
# Saved: .\preprocessing_data\train\word415_pre.png
# 돌아섰지만,
# Saved: .\preprocessing_data\train\word416_pre.png
# 있던
# Saved: .\preprocessing_data\train\word417_pre.png
# 들고
# Saved: .\preprocessing_data\train\word418_pre.png
# 토니는
# Saved: .\preprocessing_data\train\word419_pre.png
# 평소처럼
# Saved: .\preprocessing_data\train\word420_pre.png
# 햄버거를
# Saved: .\preprocessing_data\train\word421_pre.png
# 것을
# Saved: .\preprocessing_data\train\word422_pre.png
# 토니에게
# Saved: .\preprocessing_data\train\word423_pre.png
# 악행을
# Saved: .\preprocessing_data\train\word424_pre.png
# 밖에
# Saved: .\preprocessing_data\train\word425_pre.png
# 없었다
# Saved: .\preprocessing_data\train\word426_pre.png
# 순간을
# Saved: .\preprocessing_data\train\word427_pre.png
# 지켜보던
# Saved: .\preprocessing_data\train\word428_pre.png
# 게리는
# Saved: .\preprocessing_data\train\word429_pre.png
# 남은
# Saved: .\preprocessing_data\train\word430_pre.png
# 햄버거를
# Saved: .\preprocessing_data\train\word431_pre.png
# 개에게
# Saved: .\preprocessing_data\train\word432_pre.png
# 주었고
# Saved: .\preprocessing_data\train\word433_pre.png
# 그는
# Saved: .\preprocessing_data\train\word434_pre.png
# 되었다
# Saved: .\preprocessing_data\train\word435_pre.png
# 그의
# Saved: .\preprocessing_data\train\word436_pre.png
# 집에서
# Saved: .\preprocessing_data\train\word437_pre.png
# 키우기로
# Saved: .\preprocessing_data\train\word438_pre.png
# 시작했다
# Saved: .\preprocessing_data\train\word439_pre.png
# 짖기
# Saved: .\preprocessing_data\train\word440_pre.png
# 맹렬히
# Saved: .\preprocessing_data\train\word441_pre.png
# 했다
# Saved: .\preprocessing_data\train\word442_pre.png
# 때리려고
# Saved: .\preprocessing_data\train\word443_pre.png
# 그를
# Saved: .\preprocessing_data\train\word444_pre.png
# 다가가서
# Saved: .\preprocessing_data\train\word445_pre.png
# 먹는
# Saved: .\preprocessing_data\train\word446_pre.png
# 도망칠
# Saved: .\preprocessing_data\train\word447_pre.png
# 수
# Saved: .\preprocessing_data\train\word448_pre.png
# 단념하고
# Saved: .\preprocessing_data\train\word449_pre.png
# 친구가
# Saved: .\preprocessing_data\train\word450_pre.png
# 평생의
# Saved: .\preprocessing_data\train\word451_pre.png
# 6
# Saved: .\preprocessing_data\train\word452_pre.png
# 7
# Saved: .\preprocessing_data\train\word453_pre.png
# 8
# Saved: .\preprocessing_data\train\word454_pre.png
# 9
# Saved: .\preprocessing_data\train\word455_pre.png
# 결심했다
# Saved: .\preprocessing_data\train\word456_pre.png
# 10
# Saved: .\preprocessing_data\train\word457_pre.png
# 그
# Saved: .\preprocessing_data\train\word458_pre.png
# 이후로
# Saved: .\preprocessing_data\train\word459_pre.png
# 게리와
# Saved: .\preprocessing_data\train\word460_pre.png
# 개는
# Saved: .\preprocessing_data\train\word461_pre.png
# 그
# Saved: .\preprocessing_data\train\word462_pre.png
# 질린
# Saved: .\preprocessing_data\train\word463_pre.png
# 그는
# Saved: .\preprocessing_data\train\word464_pre.png
# 겁에
# Saved: .\preprocessing_data\train\word465_pre.png
# 그런데
# Saved: .\preprocessing_data\train\word466_pre.png
# 갑자기
# Saved: .\preprocessing_data\train\word467_pre.png
# 그
# Saved: .\preprocessing_data\train\word468_pre.png
# 개는
# Saved: .\preprocessing_data\train\word469_pre.png
# 동안
# Saved: .\preprocessing_data\train\word470_pre.png
# 그러는
# Saved: .\preprocessing_data\train\word471_pre.png
# 개를
# Saved: .\preprocessing_data\train\word472_pre.png
# 멈추고
# Saved: .\preprocessing_data\train\word473_pre.png
# 22
# Saved: .\preprocessing_data\train\word474_pre.png
# 6
# Saved: .\preprocessing_data\train\word475_pre.png
# 15
# Saved: .\preprocessing_data\train\word476_pre.png
# 심경
# Saved: .\preprocessing_data\train\word477_pre.png
# 분위기
# Saved: .\preprocessing_data\train\word478_pre.png
# 추론
# Saved: .\preprocessing_data\train\word479_pre.png
# 무관한
# Saved: .\preprocessing_data\train\word480_pre.png
# 문장
# Saved: .\preprocessing_data\train\word481_pre.png
# candidate
# Saved: .\preprocessing_data\train\word482_pre.png
# 후보자
# Saved: .\preprocessing_data\train\word483_pre.png
# mailbox
# Saved: .\preprocessing_data\train\word484_pre.png
# 사서함
# Saved: .\preprocessing_data\train\word485_pre.png
# long
# Saved: .\preprocessing_data\train\word486_pre.png
# desired
# Saved: .\preprocessing_data\train\word487_pre.png
# 대망의
# Saved: .\preprocessing_data\train\word488_pre.png
# sucessful
# Saved: .\preprocessing_data\train\word489_pre.png
# 성공적인
# Saved: .\preprocessing_data\train\word490_pre.png
# broad
# Saved: .\preprocessing_data\train\word491_pre.png
# 넓은
# Saved: .\preprocessing_data\train\word492_pre.png
# commercial
# Saved: .\preprocessing_data\train\word493_pre.png
# 광고
# Saved: .\preprocessing_data\train\word494_pre.png
# thorny
# Saved: .\preprocessing_data\train\word495_pre.png
# 어려운
# Saved: .\preprocessing_data\train\word496_pre.png
# liv@lihood
# Saved: .\preprocessing_data\train\word497_pre.png
# 살림
# Saved: .\preprocessing_data\train\word498_pre.png
# defire
# Saved: .\preprocessing_data\train\word499_pre.png
# 정의하다
# Saved: .\preprocessing_data\train\word500_pre.png
# 68p
# Saved: .\preprocessing_data\train\word501_pre.png
# 1번
# Saved: .\preprocessing_data\train\word502_pre.png
# 1
# Saved: .\preprocessing_data\train\word503_pre.png
# 지난주
# Saved: .\preprocessing_data\train\word504_pre.png
# Jason은
# Saved: .\preprocessing_data\train\word505_pre.png
# 40명의
# Saved: .\preprocessing_data\train\word506_pre.png
# 다른
# Saved: .\preprocessing_data\train\word507_pre.png
# 경쟁력이
# Saved: .\preprocessing_data\train\word508_pre.png
# 있는
# Saved: .\preprocessing_data\train\word509_pre.png
# 지원자들과
# Saved: .\preprocessing_data\train\word510_pre.png
# 함께
# Saved: .\preprocessing_data\train\word511_pre.png
# 뉴욕은행의
# Saved: .\preprocessing_data\train\word512_pre.png
# 새로운
# Saved: .\preprocessing_data\train\word513_pre.png
# 작업이
# Saved: .\preprocessing_data\train\word514_pre.png
# 되기
# Saved: .\preprocessing_data\train\word515_pre.png
# 위해
# Saved: .\preprocessing_data\train\word516_pre.png
# 면접을
# Saved: .\preprocessing_data\train\word517_pre.png
# 보았다
# Saved: .\preprocessing_data\train\word518_pre.png
# 화면에서
# Saved: .\preprocessing_data\train\word519_pre.png
# 엄지손가락을
# Saved: .\preprocessing_data\train\word520_pre.png
# 합격자가
# Saved: .\preprocessing_data\train\word521_pre.png
# Jason은
# Saved: .\preprocessing_data\train\word522_pre.png
# 떨리는
# Saved: .\preprocessing_data\train\word523_pre.png
# 손가락으로
# Saved: .\preprocessing_data\train\word524_pre.png
# Jason
# Saved: .\preprocessing_data\train\word525_pre.png
# 회사에
# Saved: .\preprocessing_data\train\word526_pre.png
# 이메일을
# Saved: .\preprocessing_data\train\word527_pre.png
# 없었다.
# Saved: .\preprocessing_data\train\word528_pre.png
# 수
# Saved: .\preprocessing_data\train\word529_pre.png
# 할
# Saved: .\preprocessing_data\train\word530_pre.png
# 것을
# Saved: .\preprocessing_data\train\word531_pre.png
# 다른
# Saved: .\preprocessing_data\train\word532_pre.png
# 몇번이고
# Saved: .\preprocessing_data\train\word533_pre.png
# 그는
# Saved: .\preprocessing_data\train\word534_pre.png
# 오늘
# Saved: .\preprocessing_data\train\word535_pre.png
# 아침
# Saved: .\preprocessing_data\train\word536_pre.png
# 노트북
# Saved: .\preprocessing_data\train\word537_pre.png
# 시작해
# Saved: .\preprocessing_data\train\word538_pre.png
# 깨물며
# Saved: .\preprocessing_data\train\word539_pre.png
# 결과를
# Saved: .\preprocessing_data\train\word540_pre.png
# 기다리고
# Saved: .\preprocessing_data\train\word541_pre.png
# 있었다
# Saved: .\preprocessing_data\train\word542_pre.png
# 수
# Saved: .\preprocessing_data\train\word543_pre.png
# 없었다.
# Saved: .\preprocessing_data\train\word544_pre.png
# 안심할
# Saved: .\preprocessing_data\train\word545_pre.png
# 결코
# Saved: .\preprocessing_data\train\word546_pre.png
# 그는
# Saved: .\preprocessing_data\train\word547_pre.png
# 때문에
# Saved: .\preprocessing_data\train\word548_pre.png
# 불과했기
# Saved: .\preprocessing_data\train\word549_pre.png
# 3명에
# Saved: .\preprocessing_data\train\word550_pre.png
# 결과가
# Saved: .\preprocessing_data\train\word551_pre.png
# 그의
# Saved: .\preprocessing_data\train\word552_pre.png
# 우편함에
# Saved: .\preprocessing_data\train\word553_pre.png
# 도착했고,
# Saved: .\preprocessing_data\train\word554_pre.png
# 그것을
# Saved: .\preprocessing_data\train\word555_pre.png
# 클릭했다
# Saved: .\preprocessing_data\train\word556_pre.png
# Brown을
# Saved: .\preprocessing_data\train\word557_pre.png
# 이름인
# Saved: .\preprocessing_data\train\word558_pre.png
# 그의
# Saved: .\preprocessing_data\train\word559_pre.png
# 떠서
# Saved: .\preprocessing_data\train\word560_pre.png
# 눈을
# Saved: .\preprocessing_data\train\word561_pre.png
# 조심스럽게
# Saved: .\preprocessing_data\train\word562_pre.png
# 감았다가
# Saved: .\preprocessing_data\train\word563_pre.png
# 눈을
# Saved: .\preprocessing_data\train\word564_pre.png
# 잠시
# Saved: .\preprocessing_data\train\word565_pre.png
# 명단에
# Saved: .\preprocessing_data\train\word566_pre.png
# 있는
# Saved: .\preprocessing_data\train\word567_pre.png
# 면접의
# Saved: .\preprocessing_data\train\word568_pre.png
# 다른
# Saved: .\preprocessing_data\train\word569_pre.png
# 두명의
# Saved: .\preprocessing_data\train\word570_pre.png
# 이름과
# Saved: .\preprocessing_data\train\word571_pre.png
# 함께
# Saved: .\preprocessing_data\train\word572_pre.png
# 있었다
# Saved: .\preprocessing_data\train\word573_pre.png
# 합격자
